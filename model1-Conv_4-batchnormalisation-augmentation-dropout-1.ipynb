# %%
import tensorflow as tf
import keras
from keras.callbacks import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import *
# Out:
# Using TensorFlow backend.

# %%
traindata = pd.read_csv('sign_mnist_train.csv')

# %%
trainlabel=traindata['label'].values

# %%
traindata.drop('label',inplace=True,axis=1)
trainimages = traindata.values

# %%
trainimages=trainimages.reshape(-1,28,28,1)

# %%
testdata = pd.read_csv('sign_mnist_test.csv')

# %%
testlabel=testdata['label'].values

# %%
testdata.drop('label',inplace=True,axis=1)
testimages = testdata.values

# %%
testimages=testimages.reshape(-1,28,28,1)

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
traingen=ImageDataGenerator(rotation_range=40,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,
                  shear_range=0.2,horizontal_flip=True,rescale=1/255.0,validation_split=0.2)

# %%
traindata_generator = traingen.flow(trainimages,trainlabel,subset='training')
validationdata_generator = traingen.flow(trainimages,trainlabel,subset='validation')

# %%
testgen=ImageDataGenerator(rescale=1/255.0)
testdata_generator = testgen.flow(testimages,testlabel)

# %%
model=Sequential([])

model.add(Conv2D(64,(3,3),activation="relu",input_shape=(28,28,1)))
model.add(BatchNormalization())
# model.add(Conv2D(64,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))
#model.add(Dropout(0.4))

model.add(Conv2D(128,(3,3),activation="relu"))
model.add(BatchNormalization())
# model.add(Conv2D(128,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128,(3,3),activation="relu"))
model.add(BatchNormalization())
# model.add(Conv2D(128,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128,(3,3),activation="relu"))
model.add(BatchNormalization())
# model.add(Conv2D(128,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(256,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(26,activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 64)        640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 26, 26, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 11, 11, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 26)                6682
# =================================================================
# Total params: 264,602
# Trainable params: 263,194
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
# Define a Callback class that stops training once accuracy reaches 97.0%
class myCallback(Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.985):
      print("\nReached 98.5% accuracy so cancelling training!")
      self.model.stop_training = True
callback=myCallback()

# %%
history=model.fit(traindata_generator,epochs=60,validation_data=validationdata_generator,callbacks=[callback])
# Out:
# Epoch 1/60
# 687/687 [==============================] - 11s 16ms/step - loss: 2.5432 - accuracy: 0.2390 - val_loss: 3.4136 - val_accuracy: 0.1308
# Epoch 2/60
# 687/687 [==============================] - 8s 12ms/step - loss: 1.7279 - accuracy: 0.4403 - val_loss: 4.1014 - val_accuracy: 0.2038
# Epoch 3/60
# 687/687 [==============================] - 8s 12ms/step - loss: 1.4010 - accuracy: 0.5399 - val_loss: 1.4010 - val_accuracy: 0.6270
# Epoch 4/60
# 687/687 [==============================] - 8s 12ms/step - loss: 1.1827 - accuracy: 0.6066 - val_loss: 1.6946 - val_accuracy: 0.4201
# Epoch 5/60
# 687/687 [==============================] - 8s 12ms/step - loss: 1.0542 - accuracy: 0.6455 - val_loss: 2.4903 - val_accuracy: 0.4342
# Epoch 6/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.9585 - accuracy: 0.6794 - val_loss: 2.5667 - val_accuracy: 0.5119
# Epoch 7/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.8870 - accuracy: 0.7041 - val_loss: 1.2615 - val_accuracy: 0.6671
# Epoch 8/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.8258 - accuracy: 0.7193 - val_loss: 0.9471 - val_accuracy: 0.6248
# Epoch 9/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.7792 - accuracy: 0.7375 - val_loss: 0.6548 - val_accuracy: 0.7556
# Epoch 10/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.7610 - accuracy: 0.7427 - val_loss: 0.5530 - val_accuracy: 0.7472
# Epoch 11/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.7080 - accuracy: 0.7624 - val_loss: 0.3568 - val_accuracy: 0.7449
# Epoch 12/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.6856 - accuracy: 0.7687 - val_loss: 0.5107 - val_accuracy: 0.7760
# Epoch 13/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.6487 - accuracy: 0.7816 - val_loss: 0.4931 - val_accuracy: 0.7745
# Epoch 14/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.6248 - accuracy: 0.7893 - val_loss: 0.9851 - val_accuracy: 0.7529
# Epoch 15/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.6211 - accuracy: 0.7929 - val_loss: 1.4962 - val_accuracy: 0.6168
# Epoch 16/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.5932 - accuracy: 0.7988 - val_loss: 1.0021 - val_accuracy: 0.7310
# Epoch 17/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.5678 - accuracy: 0.8096 - val_loss: 0.6844 - val_accuracy: 0.7969
# Epoch 18/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.5611 - accuracy: 0.8102 - val_loss: 1.8350 - val_accuracy: 0.6409
# Epoch 19/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.5486 - accuracy: 0.8177 - val_loss: 0.5102 - val_accuracy: 0.8161
# Epoch 20/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.5321 - accuracy: 0.8210 - val_loss: 2.2282 - val_accuracy: 0.5853
# Epoch 21/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.5317 - accuracy: 0.8234 - val_loss: 0.8461 - val_accuracy: 0.7250
# Epoch 22/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.5028 - accuracy: 0.8341 - val_loss: 1.1392 - val_accuracy: 0.6882
# Epoch 23/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4922 - accuracy: 0.8334 - val_loss: 0.4983 - val_accuracy: 0.7480
# Epoch 24/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4933 - accuracy: 0.8328 - val_loss: 1.2001 - val_accuracy: 0.6245
# Epoch 25/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4790 - accuracy: 0.8389 - val_loss: 0.3748 - val_accuracy: 0.8620
# Epoch 26/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4694 - accuracy: 0.8425 - val_loss: 0.5790 - val_accuracy: 0.8008
# Epoch 27/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4674 - accuracy: 0.8429 - val_loss: 0.2346 - val_accuracy: 0.7997
# Epoch 28/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4607 - accuracy: 0.8417 - val_loss: 0.3303 - val_accuracy: 0.8880
# Epoch 29/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4384 - accuracy: 0.8525 - val_loss: 0.7198 - val_accuracy: 0.8554
# Epoch 30/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4382 - accuracy: 0.8555 - val_loss: 0.3805 - val_accuracy: 0.8459
# Epoch 31/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4154 - accuracy: 0.8603 - val_loss: 0.2796 - val_accuracy: 0.8219
# Epoch 32/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4172 - accuracy: 0.8582 - val_loss: 0.6102 - val_accuracy: 0.8827
# Epoch 33/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4089 - accuracy: 0.8623 - val_loss: 0.1163 - val_accuracy: 0.8802
# Epoch 34/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4089 - accuracy: 0.8641 - val_loss: 1.1094 - val_accuracy: 0.7696
# Epoch 35/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4088 - accuracy: 0.8647 - val_loss: 0.2488 - val_accuracy: 0.7928
# Epoch 36/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.4020 - accuracy: 0.8641 - val_loss: 0.1934 - val_accuracy: 0.8995
# Epoch 37/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3894 - accuracy: 0.8699 - val_loss: 0.3632 - val_accuracy: 0.9117
# Epoch 38/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3883 - accuracy: 0.8715 - val_loss: 0.2121 - val_accuracy: 0.8769
# Epoch 39/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3792 - accuracy: 0.8719 - val_loss: 0.2347 - val_accuracy: 0.8964
# Epoch 40/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3917 - accuracy: 0.8708 - val_loss: 0.8656 - val_accuracy: 0.8015
# Epoch 41/60
# 687/687 [==============================] - 9s 13ms/step - loss: 0.3792 - accuracy: 0.8711 - val_loss: 0.7637 - val_accuracy: 0.8379
# Epoch 42/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3638 - accuracy: 0.8786 - val_loss: 0.3700 - val_accuracy: 0.8977
# Epoch 43/60
# 687/687 [==============================] - 9s 13ms/step - loss: 0.3598 - accuracy: 0.8782 - val_loss: 0.4010 - val_accuracy: 0.7993
# Epoch 44/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3598 - accuracy: 0.8794 - val_loss: 0.5293 - val_accuracy: 0.8020
# Epoch 45/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3597 - accuracy: 0.8800 - val_loss: 0.3606 - val_accuracy: 0.8042
# Epoch 46/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3564 - accuracy: 0.8815 - val_loss: 0.2795 - val_accuracy: 0.9226
# Epoch 47/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3430 - accuracy: 0.8860 - val_loss: 0.5296 - val_accuracy: 0.8379
# Epoch 48/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3368 - accuracy: 0.8868 - val_loss: 0.3394 - val_accuracy: 0.9122
# Epoch 49/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3432 - accuracy: 0.8853 - val_loss: 0.3486 - val_accuracy: 0.8845
# Epoch 50/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3356 - accuracy: 0.8885 - val_loss: 0.4220 - val_accuracy: 0.8430
# Epoch 51/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3424 - accuracy: 0.8843 - val_loss: 0.4412 - val_accuracy: 0.8907
# Epoch 52/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3307 - accuracy: 0.8862 - val_loss: 0.2266 - val_accuracy: 0.8742
# Epoch 53/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3315 - accuracy: 0.8872 - val_loss: 0.3253 - val_accuracy: 0.8887
# Epoch 54/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3285 - accuracy: 0.8900 - val_loss: 0.3597 - val_accuracy: 0.8829
# Epoch 55/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3288 - accuracy: 0.8895 - val_loss: 0.1150 - val_accuracy: 0.8621
# Epoch 56/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3209 - accuracy: 0.8925 - val_loss: 0.1809 - val_accuracy: 0.8148
# Epoch 57/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3296 - accuracy: 0.8917 - val_loss: 0.2081 - val_accuracy: 0.8824
# Epoch 58/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3147 - accuracy: 0.8948 - val_loss: 0.0887 - val_accuracy: 0.9048
# Epoch 59/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3271 - accuracy: 0.8883 - val_loss: 0.1151 - val_accuracy: 0.8911
# Epoch 60/60
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3100 - accuracy: 0.8958 - val_loss: 0.2291 - val_accuracy: 0.9080

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# Out:
# test accuracy: 97.28109240531921

# %%
history2=model.fit(traindata_generator,epochs=100,validation_data=validationdata_generator,callbacks=[callback],initial_epoch=60)
# Out:
# Epoch 61/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3184 - accuracy: 0.8958 - val_loss: 0.1314 - val_accuracy: 0.9055
# Epoch 62/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3008 - accuracy: 0.8973 - val_loss: 0.1739 - val_accuracy: 0.9317
# Epoch 63/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3011 - accuracy: 0.8987 - val_loss: 0.4440 - val_accuracy: 0.8304
# Epoch 64/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3145 - accuracy: 0.8969 - val_loss: 0.3446 - val_accuracy: 0.9179
# Epoch 65/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2986 - accuracy: 0.8992 - val_loss: 0.1552 - val_accuracy: 0.9073
# Epoch 66/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3025 - accuracy: 0.8996 - val_loss: 0.1296 - val_accuracy: 0.8840
# Epoch 67/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2895 - accuracy: 0.9023 - val_loss: 0.0574 - val_accuracy: 0.8884
# Epoch 68/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.3016 - accuracy: 0.9006 - val_loss: 0.1773 - val_accuracy: 0.9288
# Epoch 69/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2965 - accuracy: 0.8992 - val_loss: 0.0577 - val_accuracy: 0.8740
# Epoch 70/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2759 - accuracy: 0.9091 - val_loss: 0.3796 - val_accuracy: 0.8170
# Epoch 71/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2981 - accuracy: 0.8992 - val_loss: 0.3522 - val_accuracy: 0.9168
# Epoch 72/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2867 - accuracy: 0.9023 - val_loss: 0.6836 - val_accuracy: 0.8263
# Epoch 73/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2869 - accuracy: 0.9041 - val_loss: 0.1443 - val_accuracy: 0.9377
# Epoch 74/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2742 - accuracy: 0.9087 - val_loss: 0.1181 - val_accuracy: 0.9434
# Epoch 75/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2653 - accuracy: 0.9096 - val_loss: 0.4208 - val_accuracy: 0.9049
# Epoch 76/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2722 - accuracy: 0.9084 - val_loss: 0.1920 - val_accuracy: 0.9381
# Epoch 77/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2762 - accuracy: 0.9088 - val_loss: 0.3779 - val_accuracy: 0.9423
# Epoch 78/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2850 - accuracy: 0.9051 - val_loss: 0.1172 - val_accuracy: 0.9160
# Epoch 79/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2772 - accuracy: 0.9073 - val_loss: 0.0500 - val_accuracy: 0.9466
# Epoch 80/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2773 - accuracy: 0.9065 - val_loss: 0.3109 - val_accuracy: 0.9348
# Epoch 81/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2626 - accuracy: 0.9110 - val_loss: 0.2869 - val_accuracy: 0.9057
# Epoch 82/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2675 - accuracy: 0.9094 - val_loss: 0.2440 - val_accuracy: 0.9310
# Epoch 83/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2659 - accuracy: 0.9130 - val_loss: 0.8335 - val_accuracy: 0.7725
# Epoch 84/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2650 - accuracy: 0.9119 - val_loss: 0.1309 - val_accuracy: 0.9217
# Epoch 85/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2759 - accuracy: 0.9067 - val_loss: 0.0176 - val_accuracy: 0.9434
# Epoch 86/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2595 - accuracy: 0.9115 - val_loss: 0.0575 - val_accuracy: 0.9221
# Epoch 87/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2630 - accuracy: 0.9111 - val_loss: 0.1837 - val_accuracy: 0.9406
# Epoch 88/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2640 - accuracy: 0.9135 - val_loss: 0.0893 - val_accuracy: 0.9204
# Epoch 89/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2514 - accuracy: 0.9178 - val_loss: 0.1226 - val_accuracy: 0.9421
# Epoch 90/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2565 - accuracy: 0.9140 - val_loss: 0.0540 - val_accuracy: 0.8962
# Epoch 91/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2588 - accuracy: 0.9137 - val_loss: 0.4131 - val_accuracy: 0.8876
# Epoch 92/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2536 - accuracy: 0.9160 - val_loss: 0.1725 - val_accuracy: 0.9434
# Epoch 93/100
# 687/687 [==============================] - 9s 13ms/step - loss: 0.2589 - accuracy: 0.9147 - val_loss: 0.2241 - val_accuracy: 0.9432
# Epoch 94/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2436 - accuracy: 0.9185 - val_loss: 0.3249 - val_accuracy: 0.9441
# Epoch 95/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2646 - accuracy: 0.9105 - val_loss: 0.3807 - val_accuracy: 0.8987
# Epoch 96/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2429 - accuracy: 0.9195 - val_loss: 0.3375 - val_accuracy: 0.9432
# Epoch 97/100
# 687/687 [==============================] - 9s 13ms/step - loss: 0.2533 - accuracy: 0.9164 - val_loss: 0.4208 - val_accuracy: 0.7969
# Epoch 98/100
# 687/687 [==============================] - 9s 13ms/step - loss: 0.2359 - accuracy: 0.9235 - val_loss: 0.1195 - val_accuracy: 0.8955
# Epoch 99/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2510 - accuracy: 0.9170 - val_loss: 0.0601 - val_accuracy: 0.9603
# Epoch 100/100
# 687/687 [==============================] - 8s 12ms/step - loss: 0.2455 - accuracy: 0.9190 - val_loss: 0.1651 - val_accuracy: 0.9335

# %%
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']
loss = history2.history['loss']
val_loss = history2.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# Out:
# test accuracy: 98.13162088394165
